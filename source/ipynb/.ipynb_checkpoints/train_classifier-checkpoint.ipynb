# %%
import sys
import numpy as np
import os

sys.path.insert(0, '../')
import sys; sys.argv=['']; del sys
import matplotlib.pyplot as plt

from param import parse_argument
from models import FullModel
from models import AutoEncoder
from models import train_full_model
from models import check_loaded_weight
from models import CallbackParams
from models import encoder, decoder
# Out:
# Using TensorFlow backend.

# %%
RAW = True
if RAW:
    test_filename = 'test_raw.csv'
    data_dir = 'train_sampled_raw'
    from input_data import image_generator_xd_raw as image_generator_xd
    from input_data import df_to_image_array_xd_raw as df_to_image_array_xd
else:
    test_filename = 'test_simplified.csv'
    data_dir = 'train_sampled'
    from input_data import image_generator_xd
    from input_data import df_to_image_array_xd

# %% [markdown]
# # Setup

# %%
NCSVS = 10
SIZE = 128
BATCHSIZE = 500
BASESIZE = 256
NCATS = 340
IN_CHANNEL = 3
NUM_TOTAL_DATA = int(1020000*0.99)
STEPS = int(NUM_TOTAL_DATA/BATCHSIZE)
EPOCHS = 16
VERBOSE = 1
MODEL_PATH = '/home/jinkilee73/data/doodle/h5'
INPUT_DIR = '/home/jinkilee73/data/doodle/'

def f2cat(filename: str) -> str:
    return filename.split('.')[0]

def list_all_categories():
    files = os.listdir(os.path.join(INPUT_DIR, 'train'))
    return sorted([f2cat(f) for f in files], key=str.lower)

# %%
def apk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    if len(predicted) > k:
        predicted = predicted[:k]
    score = 0.0
    num_hits = 0.0
    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)
    if not actual:
        return 0.0
    return score / min(len(actual), k)

def mapk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    return np.mean([apk(a, p, k) for a, p in zip(actual, predicted)])

def preds2catids(predictions):
    return pd.DataFrame(np.argsort(-predictions, axis=1)[:, :3], columns=['a', 'b', 'c'])

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

# %%
list_all_categories()
# Out:
# ['airplane',
#  'alarm clock',
#  'ambulance',
#  'angel',
#  'animal migration',
#  'ant',
#  'anvil',
#  'apple',
#  'arm',
#  'asparagus',
#  'axe',
#  'backpack',
#  'banana',
#  'bandage',
#  'barn',
#  'baseball',
#  'baseball bat',
#  'basket',
#  'basketball',
#  'bat',
#  'bathtub',
#  'beach',
#  'bear',
#  'beard',
#  'bed',
#  'bee',
#  'belt',
#  'bench',
#  'bicycle',
#  'binoculars',
#  'bird',
#  'birthday cake',
#  'blackberry',
#  'blueberry',
#  'book',
#  'boomerang',
#  'bottlecap',
#  'bowtie',
#  'bracelet',
#  'brain',
#  'bread',
#  'bridge',
#  'broccoli',
#  'broom',
#  'bucket',
#  'bulldozer',
#  'bus',
#  'bush',
#  'butterfly',
#  'cactus',
#  'cake',
#  'calculator',
#  'calendar',
#  'camel',
#  'camera',
#  'camouflage',
#  'campfire',
#  'candle',
#  'cannon',
#  'canoe',
#  'car',
#  'carrot',
#  'castle',
#  'cat',
#  'ceiling fan',
#  'cell phone',
#  'cello',
#  'chair',
#  'chandelier',
#  'church',
#  'circle',
#  'clarinet',
#  'clock',
# ...

# %% [markdown]
# # Train full_model

# %%
model_param = {
    'input_shape':(SIZE, SIZE, IN_CHANNEL),
    'weights':None,
    'classes':NCATS
}
#from keras.applications.inception_resnet_v2 import InceptionResNetV2
#mobile = InceptionResNetV2(**model_param)

from tensorflow.contrib.keras.api.keras.applications.xception import Xception
mobile = Xception(**model_param)

# %%
mobile.summary()
print(len(mobile.layers))
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 128, 128, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Conv2D)            (None, 63, 63, 32)    864         input_1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_bn (BatchNormalizat (None, 63, 63, 32)    128         block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_act (Activation)    (None, 63, 63, 32)    0           block1_conv1_bn[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
random_number = np.random.randint(0, 1000)
model_name = '%s-%d_%d_%d_%04d' % (mobile.name, SIZE, IN_CHANNEL, BATCHSIZE, random_number)
model_json_filename = os.path.join(MODEL_PATH, model_name + '.json')
model_h5_filename = os.path.join(MODEL_PATH, model_name + '.h5')
print(model_json_filename, model_h5_filename)
# Out:
# /data/doodle/h5/xception-128_3_500_0475.json /data/doodle/h5/xception-128_3_500_0475.h5

# %%
model_json = mobile.to_json()
with open(model_json_filename, "w") as json_file:
    json_file.write(model_json)

# %%
from models import CallbackParams
callbackparams = CallbackParams(model_h5_filename, 'val_top_3_accuracy')

# %%
from keras.optimizers import RMSprop, Adam, Nadam
from keras.utils.training_utils import multi_gpu_model
from keras.metrics import top_k_categorical_accuracy, categorical_crossentropy, categorical_accuracy

try:
    mobile = multi_gpu_model(mobile, gpus=2)
except:
    pass
optimizer_param = {
    'optimizer': Adam(lr=0.002),
    'loss':'categorical_crossentropy',
    'metrics':[categorical_crossentropy, categorical_accuracy, top_3_accuracy],
}
mobile.compile(**optimizer_param)

# %%
import pandas as pd
import os
from tensorflow import keras
from keras.metrics import top_k_categorical_accuracy, categorical_crossentropy, categorical_accuracy
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

train_datagen = image_generator_xd(SIZE, BATCHSIZE, ks=range(NCSVS - 1), time_color=True)
validation_datagen = image_generator_xd(SIZE, BATCHSIZE, ks=range(NCSVS-1, NCSVS))

valid_df = pd.read_csv(os.path.join('/data/doodle/%s' % data_dir, 'train_k{}.csv.gz'.format(NCSVS - 1)), nrows=34000)
x_valid = df_to_image_array_xd(valid_df, SIZE)
y_valid = keras.utils.to_categorical(valid_df.y, num_classes=NCATS)

# %%
x, y = next(train_datagen)
y = np.argmax(y, axis=1)
print(x.shape)
idx = np.random.randint(0, 255)
tmp_x = x[idx].reshape((SIZE, SIZE, IN_CHANNEL))
plt.imshow(tmp_x)

# label category
cat_dict = list_all_categories()
cat_dict[y[idx]]
# Out:
# (500, 128, 128, 3)
# 'tiger'

# %%
x, y = next(validation_datagen)
y = np.argmax(y, axis=1)
print(x.shape)
idx = np.random.randint(0, 255)
tmp_x = x[idx].reshape((SIZE, SIZE, IN_CHANNEL))
plt.imshow(tmp_x)

# label category
cat_dict = list_all_categories()
cat_dict[y[idx]]
# Out:
# (500, 128, 128, 3)
# 'fan'

# %%
idx = np.random.randint(0, 255)
tmp_x = x_valid[idx].reshape((SIZE,SIZE, IN_CHANNEL))
tmp_y = np.argmax(y_valid, axis=1)
plt.imshow(tmp_x)

# label category
cat_dict[tmp_y[idx]]
# Out:
# 'anvil'

# %%
n = 8
layer = 1
fig, axs = plt.subplots(nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))
for i in range(n**2):
    ax = axs[i // n, i % n]
    #a = (-x[i]+1)/2
    a = ax.imshow(x[i, :, :, layer])
    a = ax.axis('off')
plt.tight_layout()

# %%
font = {'fontsize':50}
idx = np.random.randint(0, BATCHSIZE)
fig, axs = plt.subplots(1, 4, figsize=(48, 12), sharey=True)
axs[0].imshow(x[idx,:,:,0])
axs[1].imshow(x[idx,:,:,1])
axs[2].imshow(x[idx,:,:,2])
axs[3].imshow(x[idx].reshape((SIZE, SIZE, 3)))

axs[0].set_title('layer 0', fontdict=font)
axs[1].set_title('layer 1', fontdict=font)
axs[2].set_title('layer 2', fontdict=font)
axs[3].set_title('whole image', fontdict=font)
# Out:
# Text(0.5,1,'whole image')

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.75, patience=3, min_delta=0.001,
                          mode='max', min_lr=1e-5, verbose=1),
    ModelCheckpoint(model_h5_filename, monitor='val_top_3_accuracy', mode='max', save_best_only=True,
                    save_weights_only=True),
]

hist = mobile.fit_generator(
    train_datagen, steps_per_epoch=STEPS, epochs=70, verbose=1,
    validation_data=validation_datagen, validation_steps=680, 
    callbacks = callbacks
)
# Out:
# Epoch 1/70
# 2019/2019 [==============================] - 2353s 1s/step - loss: 1.5079 - categorical_crossentropy: 1.5079 - categorical_accuracy: 0.6309 - top_3_accuracy: 0.8109 - val_loss: 1.3083 - val_categorical_crossentropy: 1.3083 - val_categorical_accuracy: 0.6689 - val_top_3_accuracy: 0.8480
# Epoch 2/70
# 2019/2019 [==============================] - 2313s 1s/step - loss: 1.0370 - categorical_crossentropy: 1.0370 - categorical_accuracy: 0.7333 - top_3_accuracy: 0.8896 - val_loss: 1.1460 - val_categorical_crossentropy: 1.1460 - val_categorical_accuracy: 0.7031 - val_top_3_accuracy: 0.8737
# Epoch 3/70
# 2019/2019 [==============================] - 2316s 1s/step - loss: 0.9339 - categorical_crossentropy: 0.9339 - categorical_accuracy: 0.7578 - top_3_accuracy: 0.9038 - val_loss: 0.9783 - val_categorical_crossentropy: 0.9783 - val_categorical_accuracy: 0.7434 - val_top_3_accuracy: 0.8987
# Epoch 4/70
# ...

# %%
print(model_json_filename, model_h5_filename)

# %%
mobile.save_weights(model_h5_filename)

# %% [markdown]
# # Load full_model

# %%
from keras.models import model_from_json
from keras.utils.training_utils import multi_gpu_model

model_json_filename = '/data/doodle/h5/inception_resnet_v2-128_3_500_0803.json'
model_h5_filename = '/data/doodle/h5/inception_resnet_v2-128_3_500_0803.h5'

json_file = open(model_json_filename, "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
try:
    #1/0
    loaded_model = multi_gpu_model(loaded_model, gpus=2)
except ZeroDivisionError:
    pass

# %%
loaded_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128, 128, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 128, 128, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# inception_resnet_v2 (Model)     (None, 340)          54859316    lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from keras.models import load_model
loaded_model.load_weights(model_h5_filename)

# %%
import pandas as pd
test = pd.read_csv('/data/doodle/%s' % test_filename)
test.head()
x_test = df_to_image_array_xd(test, SIZE)
print(test.shape, x_test.shape)
print('Test array memory {:.2f} GB'.format(x_test.nbytes / 1024.**3 ))
# Out:
# (112199, 3) (112199, 128, 128, 3)
# Test array memory 20.54 GB

# %%
test_predictions = loaded_model.predict(x_test, batch_size=128, verbose=1)
top3 = preds2catids(test_predictions)
top3.head()
# Out:
# 112199/112199 [==============================] - 231s 2ms/step
#      a    b    c
# 0  234  281   13
# 1  144   36  125
# 2  305   62  110
# 3  187  111  303
# 4   56  113  112

# %%
cat_dict = list_all_categories()
cat_dict = [cat.replace(' ', '_') for cat in cat_dict]

# %%
top3.loc[:,'a'] = list(map(lambda x: cat_dict[x], top3.a))
top3.loc[:,'b'] = list(map(lambda x: cat_dict[x], top3.b))
top3.loc[:,'c'] = list(map(lambda x: cat_dict[x], top3.c))

# %%
top3.loc[:, 'word'] = [' '.join((a, b, c)) for a, b, c in zip(top3.a, top3.b, top3.c)]

# %%
top3.head()
# Out:
#                          a          b             c  \
# 0                    radio     stereo       bandage
# 1              hockey_puck  bottlecap    frying_pan
# 2  The_Great_Wall_of_China     castle         fence
# 3                 mountain     finger          tent
# 4                 campfire  fireplace  fire_hydrant
#
#                                    word
# 0                  radio stereo bandage
# 1      hockey_puck bottlecap frying_pan
# 2  The_Great_Wall_of_China castle fence
# 3                  mountain finger tent
# 4       campfire fireplace fire_hydrant

# %%
submission_df = pd.concat([test.key_id, top3.word], axis=1)
submission_df.to_csv('/data/doodle/submission/tmp.csv', index=False)

# %% [markdown]
# # Retrain model

# %%
from keras.models import model_from_json
from keras.utils.training_utils import multi_gpu_model

model_json_filename = '/data/doodle/h5/inception_resnet_v2-128_3_450_0827.json'
model_h5_filename = '/data/doodle/h5/inception_resnet_v2-128_3_450_0827.h5'

json_file = open(model_json_filename, "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
try:
    #1/0
    loaded_model = multi_gpu_model(loaded_model, gpus=2)
except ZeroDivisionError:
    pass

# %%
from keras.models import load_model
loaded_model.load_weights(model_h5_filename)

# %%
from models import CallbackParams
callbackparams = CallbackParams(model_h5_filename, 'val_top_3_accuracy')

# %%
from keras.optimizers import RMSprop, Adam, Nadam
from keras.utils.training_utils import multi_gpu_model
from keras.metrics import top_k_categorical_accuracy, categorical_crossentropy, categorical_accuracy

optimizer_param = {
    'optimizer': Nadam(lr=0.001125000009778887),
    'loss':'categorical_crossentropy',
    'metrics':[categorical_crossentropy, categorical_accuracy, top_3_accuracy],
}
loaded_model.compile(**optimizer_param)

# %%
import pandas as pd
import os
from tensorflow import keras
from keras.metrics import top_k_categorical_accuracy, categorical_crossentropy, categorical_accuracy
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

train_datagen = image_generator_xd(SIZE, BATCHSIZE, ks=range(NCSVS - 1), time_color=True)
validation_datagen = image_generator_xd(SIZE, BATCHSIZE, ks=range(NCSVS-1, NCSVS))

valid_df = pd.read_csv(os.path.join('/data/doodle/%s' % data_dir, 'train_k{}.csv.gz'.format(NCSVS - 1)), nrows=34000)
x_valid = df_to_image_array_xd(valid_df, SIZE)
y_valid = keras.utils.to_categorical(valid_df.y, num_classes=NCATS)

# %%
x, y = next(train_datagen)
y = np.argmax(y, axis=1)
print(x.shape)
idx = np.random.randint(0, 255)
tmp_x = x[idx].reshape((SIZE, SIZE, IN_CHANNEL))
plt.imshow(tmp_x)

# label category
cat_dict = list_all_categories()
cat_dict[y[idx]]
# Out:
# (450, 128, 128, 3)
# 'teapot'

# %%
x, y = next(validation_datagen)
y = np.argmax(y, axis=1)
print(x.shape)
idx = np.random.randint(0, 255)
tmp_x = x[idx].reshape((SIZE, SIZE, IN_CHANNEL))
plt.imshow(tmp_x)

# label category
cat_dict = list_all_categories()
cat_dict[y[idx]]
# Out:
# (450, 128, 128, 3)
# 'wine glass'

# %%
idx = np.random.randint(0, 255)
tmp_x = x_valid[idx].reshape((SIZE,SIZE, IN_CHANNEL))
tmp_y = np.argmax(y_valid, axis=1)
plt.imshow(tmp_x)

# label category
cat_dict[tmp_y[idx]]
# Out:
# 'pineapple'

# %%
n = 8
layer = 1
fig, axs = plt.subplots(nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))
for i in range(n**2):
    ax = axs[i // n, i % n]
    #a = (-x[i]+1)/2
    a = ax.imshow(x[i, :, :, layer])
    a = ax.axis('off')
plt.tight_layout()

# %%
font = {'fontsize':50}
idx = np.random.randint(0, BATCHSIZE)
fig, axs = plt.subplots(1, 4, figsize=(48, 12), sharey=True)
axs[0].imshow(x[idx,:,:,0])
axs[1].imshow(x[idx,:,:,1])
axs[2].imshow(x[idx,:,:,2])
axs[3].imshow(x[idx].reshape((SIZE, SIZE, 3)))

axs[0].set_title('layer 0', fontdict=font)
axs[1].set_title('layer 1', fontdict=font)
axs[2].set_title('layer 2', fontdict=font)
axs[3].set_title('whole image', fontdict=font)
# Out:
# Text(0.5,1,'whole image')

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.75, patience=3, min_delta=0.001,
                          mode='max', min_lr=1e-5, verbose=1),
    ModelCheckpoint(model_h5_filename, monitor='val_top_3_accuracy', mode='max', save_best_only=True,
                    save_weights_only=True),
]

hist = loaded_model.fit_generator(
    train_datagen, steps_per_epoch=STEPS, epochs=70, verbose=1,
    validation_data=validation_datagen, validation_steps=100, 
    callbacks = callbacks
)
# Out:
# Epoch 1/70
# 2244/2244 [==============================] - 1896s 845ms/step - loss: 0.5333 - categorical_crossentropy: 0.5333 - categorical_accuracy: 0.8563 - top_3_accuracy: 0.9525 - val_loss: 0.6783 - val_categorical_crossentropy: 0.6783 - val_categorical_accuracy: 0.8280 - val_top_3_accuracy: 0.9383
# Epoch 2/70
# 2244/2244 [==============================] - 1843s 821ms/step - loss: 0.5294 - categorical_crossentropy: 0.5294 - categorical_accuracy: 0.8566 - top_3_accuracy: 0.9530 - val_loss: 0.6858 - val_categorical_crossentropy: 0.6858 - val_categorical_accuracy: 0.8276 - val_top_3_accuracy: 0.9367
# Epoch 3/70
# 2244/2244 [==============================] - 1836s 818ms/step - loss: 0.5310 - categorical_crossentropy: 0.5310 - categorical_accuracy: 0.8562 - top_3_accuracy: 0.9527 - val_loss: 0.6699 - val_categorical_crossentropy: 0.6699 - val_categorical_accuracy: 0.8269 - val_top_3_accuracy: 0.9384
# Epoch 4/70
# ...

# %% [markdown]
# Epoch 1/70
# 2244/2244 [==============================] - 2268s 1s/step - loss: 0.7970 - categorical_crossentropy: 0.7970 - categorical_accuracy: 0.7914 - top_3_accuracy: 0.9215 - val_loss: 0.8586 - val_categorical_crossentropy: 0.8586 - val_categorical_accuracy: 0.7748 - val_top_3_accuracy: 0.9138
# Epoch 2/70
# 2244/2244 [==============================] - 2196s 979ms/step - loss: 0.8187 - categorical_crossentropy: 0.8187 - categorical_accuracy: 0.7865 - top_3_accuracy: 0.9184 - val_loss: 0.7921 - val_categorical_crossentropy: 0.7921 - val_categorical_accuracy: 0.7929 - val_top_3_accuracy: 0.9223
# Epoch 3/70
# 2244/2244 [==============================] - 2196s 979ms/step - loss: 0.7536 - categorical_crossentropy: 0.7536 - categorical_accuracy: 0.8023 - top_3_accuracy: 0.9270 - val_loss: 0.7780 - val_categorical_crossentropy: 0.7780 - val_categorical_accuracy: 0.7956 - val_top_3_accuracy: 0.9241
# Epoch 4/70
# 2244/2244 [==============================] - 2210s 985ms/step - loss: 0.7573 - categorical_crossentropy: 0.7573 - categorical_accuracy: 0.8009 - top_3_accuracy: 0.9266 - val_loss: 0.7878 - val_categorical_crossentropy: 0.7878 - val_categorical_accuracy: 0.7925 - val_top_3_accuracy: 0.9235
# Epoch 5/70
# 2244/2244 [==============================] - 2200s 980ms/step - loss: 0.7482 - categorical_crossentropy: 0.7482 - categorical_accuracy: 0.8036 - top_3_accuracy: 0.9279 - val_loss: 0.7951 - val_categorical_crossentropy: 0.7951 - val_categorical_accuracy: 0.7912 - val_top_3_accuracy: 0.9220
# Epoch 6/70
# 2244/2244 [==============================] - 2202s 981ms/step - loss: 0.7455 - categorical_crossentropy: 0.7455 - categorical_accuracy: 0.8038 - top_3_accuracy: 0.9281 - val_loss: 0.7635 - val_categorical_crossentropy: 0.7635 - val_categorical_accuracy: 0.7985 - val_top_3_accuracy: 0.9267
# Epoch 7/70
# 2244/2244 [==============================] - 2199s 980ms/step - loss: 0.7322 - categorical_crossentropy: 0.7322 - categorical_accuracy: 0.8071 - top_3_accuracy: 0.9299 - val_loss: 0.7550 - val_categorical_crossentropy: 0.7550 - val_categorical_accuracy: 0.8009 - val_top_3_accuracy: 0.9272
# Epoch 8/70
# 2244/2244 [==============================] - 2194s 978ms/step - loss: 0.7299 - categorical_crossentropy: 0.7299 - categorical_accuracy: 0.8074 - top_3_accuracy: 0.9301 - val_loss: 0.7354 - val_categorical_crossentropy: 0.7354 - val_categorical_accuracy: 0.8067 - val_top_3_accuracy: 0.9294
# Epoch 9/70
# 2244/2244 [==============================] - 2199s 980ms/step - loss: 0.7279 - categorical_crossentropy: 0.7279 - categorical_accuracy: 0.8081 - top_3_accuracy: 0.9302 - val_loss: 0.7381 - val_categorical_crossentropy: 0.7381 - val_categorical_accuracy: 0.8063 - val_top_3_accuracy: 0.9292
# Epoch 10/70
# 2244/2244 [==============================] - 2202s 981ms/step - loss: 0.7078 - categorical_crossentropy: 0.7078 - categorical_accuracy: 0.8133 - top_3_accuracy: 0.9332 - val_loss: 0.7365 - val_categorical_crossentropy: 0.7365 - val_categorical_accuracy: 0.8067 - val_top_3_accuracy: 0.9303
# Epoch 11/70
# 2244/2244 [==============================] - 2196s 979ms/step - loss: 0.6516 - categorical_crossentropy: 0.6516 - categorical_accuracy: 0.8262 - top_3_accuracy: 0.9393 - val_loss: 0.7086 - val_categorical_crossentropy: 0.7086 - val_categorical_accuracy: 0.8143 - val_top_3_accuracy: 0.9338
# Epoch 12/70
# 2244/2244 [==============================] - 2201s 981ms/step - loss: 0.6544 - categorical_crossentropy: 0.6544 - categorical_accuracy: 0.8251 - top_3_accuracy: 0.9395 - val_loss: 0.7206 - val_categorical_crossentropy: 0.7206 - val_categorical_accuracy: 0.8110 - val_top_3_accuracy: 0.9317
# Epoch 13/70
# 2244/2244 [==============================] - 2201s 981ms/step - loss: 0.6575 - categorical_crossentropy: 0.6575 - categorical_accuracy: 0.8243 - top_3_accuracy: 0.9390 - val_loss: 0.7090 - val_categorical_crossentropy: 0.7090 - val_categorical_accuracy: 0.8135 - val_top_3_accuracy: 0.9329
# Epoch 14/70
# 2244/2244 [==============================] - 2200s 980ms/step - loss: 0.6532 - categorical_crossentropy: 0.6532 - categorical_accuracy: 0.8259 - top_3_accuracy: 0.9392 - val_loss: 0.7012 - val_categorical_crossentropy: 0.7012 - val_categorical_accuracy: 0.8157 - val_top_3_accuracy: 0.9339
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.001500000071246177.
# Epoch 15/70
# 2244/2244 [==============================] - 2206s 983ms/step - loss: 0.6394 - categorical_crossentropy: 0.6394 - categorical_accuracy: 0.8296 - top_3_accuracy: 0.9409 - val_loss: 0.6762 - val_categorical_crossentropy: 0.6762 - val_categorical_accuracy: 0.8204 - val_top_3_accuracy: 0.9374
# Epoch 16/70
# 2244/2244 [==============================] - 2209s 984ms/step - loss: 0.6449 - categorical_crossentropy: 0.6449 - categorical_accuracy: 0.8291 - top_3_accuracy: 0.9403 - val_loss: 0.6702 - val_categorical_crossentropy: 0.6702 - val_categorical_accuracy: 0.8236 - val_top_3_accuracy: 0.9373
# Epoch 17/70
# 2244/2244 [==============================] - 2202s 981ms/step - loss: 0.6307 - categorical_crossentropy: 0.6307 - categorical_accuracy: 0.8316 - top_3_accuracy: 0.9417 - val_loss: 0.6719 - val_categorical_crossentropy: 0.6719 - val_categorical_accuracy: 0.8216 - val_top_3_accuracy: 0.9378
# Epoch 18/70
# 2244/2244 [==============================] - 2205s 983ms/step - loss: 0.6285 - categorical_crossentropy: 0.6285 - categorical_accuracy: 0.8333 - top_3_accuracy: 0.9422 - val_loss: 0.6728 - val_categorical_crossentropy: 0.6728 - val_categorical_accuracy: 0.8227 - val_top_3_accuracy: 0.9370
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.001125000009778887.
# Epoch 19/70
# 2244/2244 [==============================] - 2203s 982ms/step - loss: 0.6148 - categorical_crossentropy: 0.6148 - categorical_accuracy: 0.8361 - top_3_accuracy: 0.9440 - val_loss: 0.6539 - val_categorical_crossentropy: 0.6539 - val_categorical_accuracy: 0.8268 - val_top_3_accuracy: 0.9399
# Epoch 20/70
# 2244/2244 [==============================] - 2206s 983ms/step - loss: 0.6141 - categorical_crossentropy: 0.6141 - categorical_accuracy: 0.8367 - top_3_accuracy: 0.9440 - val_loss: 0.6546 - val_categorical_crossentropy: 0.6546 - val_categorical_accuracy: 0.8263 - val_top_3_accuracy: 0.9390
# Epoch 21/70
# 2243/2244 [============================>.] - ETA: 0s - loss: 0.5359 - categorical_crossentropy: 0.5359 - categorical_accuracy: 0.8549 - top_3_accuracy: 0.9524

# %%
0.001125000009778887
